# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'originated', 'as', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.327468
# Nearest to than: lombok, refit, turns, sidecar, callahan, lahoud, intervening, generate,
# Nearest to are: skit, endeavour, lay, suspicions, subordinated, deists, precedent, lions,
# Nearest to while: incorporate, conics, pedophilia, crest, landtag, cones, prominent, benefit,
# Nearest to over: match, bcd, icrc, cos, carducci, pappus, incorporeal, fantasia,
# Nearest to from: abandonware, squads, cage, sure, khayy, bitmaps, battista, kitzmiller,
# Nearest to so: pathogen, evagrius, hilaire, coached, thera, mosquitoes, backplane, caricatures,
# Nearest to six: tended, fabricated, theophoric, inv, gomer, cryptanalyst, westland, bleachers,
# Nearest to world: cuneiform, expressing, nonconfirmative, dwarfed, lollards, geodesic, deposition, transmigration,
# Nearest to d: tyne, americanized, saya, iskra, stele, kare, cysteine, interval,
# Nearest to war: sabra, domed, takeoff, voiceless, tierney, aztecs, polymyositis, unser,
# Nearest to some: belshazzar, ours, wade, facilitated, tries, diversion, viet, loathed,
# Nearest to american: epidemiological, kbit, rosamund, target, elegiac, shave, sseldorf, bomb,
# Nearest to this: cri, pied, spikes, baraka, disregarding, mirage, navigated, elbe,
# Nearest to two: amour, monastics, sketch, airstrip, sandworms, nerve, preoccupied, feelin,
# Nearest to history: chthonic, apap, nanotubes, bunker, wavelength, doping, sores, activating,
# Nearest to an: martians, brixton, nonsense, jog, reset, alleviating, cham, porte,
# Average loss at step 2000: 4.355733
# Average loss at step 4000: 3.863463
# Average loss at step 6000: 3.792470
# Average loss at step 8000: 3.681054
# Average loss at step 10000: 3.614604
# Nearest to than: wondered, lombok, sidecar, turns, swords, intervening, michelob, paget,
# Nearest to are: were, is, have, adriatic, kashubian, nils, pentagons, satanic,
# Nearest to while: incorporate, conics, widescreen, prominent, treachery, cones, mcdonald, mcgowan,
# Nearest to over: match, pappus, fantasia, icrc, pesticides, east, counternarcotics, ahaz,
# Nearest to from: on, after, between, khayy, in, by, into, solve,
# Nearest to so: ghilzai, luigi, dismayed, coached, pathogen, deng, hardly, tops,
# Nearest to six: eight, five, seven, four, three, nine, zero, two,
# Nearest to world: boreal, theorized, transmigration, digit, danielle, skirt, lewinsky, population,
# Nearest to d: americanized, tyne, interval, nationals, stele, and, kare, vow,
# Nearest to war: sabra, dearth, tierney, domed, unsatisfied, aztecs, statism, voiceless,
# Nearest to some: many, other, soulful, factional, any, belshazzar, these, several,
# Nearest to american: english, target, supersede, dorne, canadian, shave, and, kbit,
# Nearest to this: it, the, which, ona, immoral, a, ostrich, that,
# Nearest to two: three, five, four, eight, six, seven, zero, nine,
# Nearest to history: chthonic, bunker, hobbs, film, explanation, diatessaron, sonny, language,
# Nearest to an: the, sacrifice, erasure, brixton, laborers, confocal, tatra, matriarch,
# Average loss at step 12000: 3.608629
# Average loss at step 14000: 3.565663
# Average loss at step 16000: 3.411444
# Average loss at step 18000: 3.458597
# Average loss at step 20000: 3.542788
# Nearest to than: or, wondered, carrera, sidecar, lombok, turns, bernd, swords,
# Nearest to are: were, is, have, coagulation, nils, machinima, be, paparazzi,
# Nearest to while: incorporate, prominent, mcdonald, mcgowan, conics, treachery, cones, lightweight,
# Nearest to over: match, through, fantasia, counternarcotics, pappus, icrc, csv, pesticides,
# Nearest to from: between, after, into, in, through, for, khayy, hip,
# Nearest to so: ghilzai, lighthouses, too, tops, luigi, evagrius, caecilius, deng,
# Nearest to six: seven, eight, five, nine, three, four, zero, two,
# Nearest to world: boreal, gorky, theorized, digit, resonating, margin, population, pasture,
# Nearest to d: b, nationals, interval, tanker, besson, antipodes, strains, vow,
# Nearest to war: dearth, sabra, tierney, unsatisfied, plebs, druids, gregorio, executors,
# Nearest to some: many, these, several, other, soulful, all, any, most,
# Nearest to american: canadian, british, french, english, banking, german, hetfield, supersede,
# Nearest to this: it, which, a, the, kazantzakis, riverine, that, ostrich,
# Nearest to two: three, five, four, six, eight, seven, one, zero,
# Nearest to history: buena, hobbs, presence, sell, sonny, amway, football, corporation,
# Nearest to an: tatra, erasure, phospholipids, the, patriot, outboard, sacrifice, known,
# Average loss at step 22000: 3.502835
# Average loss at step 24000: 3.496583
# Average loss at step 26000: 3.486384
# Average loss at step 28000: 3.477976
# Average loss at step 30000: 3.499305
# Nearest to than: carrera, or, wondered, much, sidecar, attire, lombok, bernd,
# Nearest to are: were, have, glorifying, is, include, be, nils, coagulation,
# Nearest to while: but, lightweight, however, incorporate, mcgowan, divulge, muted, although,
# Nearest to over: fantasia, counternarcotics, through, icrc, pickwick, pesticides, match, training,
# Nearest to from: into, by, between, khayy, after, through, bog, in,
# Nearest to so: too, ghilzai, longevity, deng, luigi, reinstate, evagrius, caecilius,
# Nearest to six: four, eight, seven, nine, five, three, zero, two,
# Nearest to world: boreal, population, earth, gorky, successes, kingpin, metallurgical, initial,
# Nearest to d: b, nationals, besson, strains, tanker, midfielders, vow, bun,
# Nearest to war: dearth, sabra, antipope, unsatisfied, candles, tierney, gregorio, shareholder,
# Nearest to some: many, these, several, other, their, all, various, most,
# Nearest to american: british, canadian, english, french, german, australian, italian, banking,
# Nearest to this: which, it, that, the, revisions, some, ostrich, riverine,
# Nearest to two: three, four, one, five, seven, six, eight, zero,
# Nearest to history: presence, buena, title, gout, corporation, football, language, hobbs,
# Nearest to an: phospholipids, sula, tatra, relapsed, matriarch, aim, thynne, scraped,
# Average loss at step 32000: 3.499523
# Average loss at step 34000: 3.494566
# Average loss at step 36000: 3.462253
# Average loss at step 38000: 3.299914
# Average loss at step 40000: 3.432022
# Nearest to than: or, carrera, wondered, bernd, attire, session, much, slightly,
# Nearest to are: were, is, be, have, while, glorifying, these, peroxides,
# Nearest to while: although, but, when, however, were, are, after, where,
# Nearest to over: through, wind, from, counternarcotics, match, fantasia, between, categorical,
# Nearest to from: into, through, in, toward, of, between, after, khayy,
# Nearest to so: too, lighthouses, deng, longevity, evagrius, reinstate, refounded, airspeed,
# Nearest to six: seven, eight, five, four, nine, three, two, one,
# Nearest to world: sf, successes, boreal, gorky, population, theorized, wellcome, kingpin,
# Nearest to d: b, besson, nationals, tyne, vow, tanker, midfielders, r,
# Nearest to war: dearth, sabra, gregorio, guiana, candles, tierney, mehr, plebs,
# Nearest to some: many, these, several, any, various, other, their, the,
# Nearest to american: british, english, canadian, french, australian, supersede, russian, raymond,
# Nearest to this: which, it, that, the, he, any, ostrich, another,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to history: presence, corporation, opinion, list, gout, pastors, neo, buena,
# Nearest to an: phospholipids, archangels, tatra, thynne, glycerol, sting, pathogens, arf,
# Average loss at step 42000: 3.434301
# Average loss at step 44000: 3.454600
# Average loss at step 46000: 3.452224
# Average loss at step 48000: 3.353681
# Average loss at step 50000: 3.382212
# Nearest to than: or, carrera, but, nsdap, slightly, wondered, much, lombok,
# Nearest to are: were, is, have, these, glorifying, although, being, be,
# Nearest to while: although, when, however, but, after, and, where, for,
# Nearest to over: through, win, fantasia, refuge, michelob, counternarcotics, training, workability,
# Nearest to from: into, through, in, gurps, uzbeks, toward, boudica, between,
# Nearest to so: too, before, airspeed, caecilius, longevity, refounded, lighthouses, caricatures,
# Nearest to six: eight, seven, four, five, nine, three, two, zero,
# Nearest to world: sf, largest, successes, kingpin, boreal, bg, population, gorky,
# Nearest to d: b, r, j, vow, tyne, nationals, e, h,
# Nearest to war: dearth, sabra, gregorio, shareholder, candles, presupposition, reshaped, executors,
# Nearest to some: many, several, these, various, any, both, other, most,
# Nearest to american: british, english, french, australian, international, canadian, supersede, italian,
# Nearest to this: which, it, the, he, some, there, levied, equiv,
# Nearest to two: three, six, one, four, seven, five, eight, zero,
# Nearest to history: corporation, presence, pastors, opinion, ethnically, neo, ibanez, gout,
# Nearest to an: the, phospholipids, tatra, crashing, arf, bleach, pathogens, archangels,
# Average loss at step 52000: 3.436617
# Average loss at step 54000: 3.425581
# Average loss at step 56000: 3.445260
# Average loss at step 58000: 3.400279
# Average loss at step 60000: 3.394172
# Nearest to than: or, and, slightly, much, wondered, but, carrera, nsdap,
# Nearest to are: were, is, have, glorifying, those, these, nils, be,
# Nearest to while: although, when, after, however, before, were, without, and,
# Nearest to over: through, between, around, michelob, win, into, accents, fantasia,
# Nearest to from: into, through, between, toward, in, by, kriol, uzbeks,
# Nearest to so: too, caecilius, airspeed, lighthouses, longevity, reinstate, vauxhall, probing,
# Nearest to six: five, eight, four, nine, seven, three, one, zero,
# Nearest to world: sf, largest, population, successes, earth, bei, collaborating, searing,
# Nearest to d: b, r, j, h, c, tyne, where, philipp,
# Nearest to war: sabra, executors, dearth, presupposition, reshaped, cia, gregorio, cruelty,
# Nearest to some: many, several, these, any, various, this, their, each,
# Nearest to american: british, australian, english, french, supersede, derbyshire, international, canadian,
# Nearest to this: which, it, that, there, some, the, what, a,
# Nearest to two: four, three, five, six, one, eight, seven, nine,
# Nearest to history: origins, list, geography, viol, opinion, associate, pastors, dissolution,
# Nearest to an: tatra, erasure, phospholipids, amtrak, thynne, editable, the, arf,
# Average loss at step 62000: 3.237763
# Average loss at step 64000: 3.253001
# Average loss at step 66000: 3.404216
# Average loss at step 68000: 3.392879
# Average loss at step 70000: 3.358096
# Nearest to than: or, carrera, but, wondered, slightly, much, regulate, bernd,
# Nearest to are: were, have, is, these, while, include, including, those,
# Nearest to while: although, when, and, however, before, after, though, are,
# Nearest to over: through, around, counternarcotics, workability, win, fantasia, about, foray,
# Nearest to from: through, into, refrigerants, khayy, toward, by, between, in,
# Nearest to so: too, airspeed, reinstate, probing, longevity, caecilius, later, vauxhall,
# Nearest to six: eight, seven, four, nine, five, three, two, zero,
# Nearest to world: sf, gorky, bg, successes, country, ideologue, bbb, earth,
# Nearest to d: b, j, philipp, vow, r, tyne, cysteine, craters,
# Nearest to war: executors, dearth, sabra, presupposition, heritage, cia, guiana, deception,
# Nearest to some: many, several, these, various, any, most, all, both,
# Nearest to american: british, australian, english, supersede, derbyshire, logging, international, french,
# Nearest to this: it, which, that, the, there, another, she, he,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to history: list, origins, description, review, opinion, purging, viol, corporation,
# Nearest to an: the, editable, popularizer, thynne, phospholipids, pathogens, aggregated, roused,
# Average loss at step 72000: 3.367808
# Average loss at step 74000: 3.350879
# Average loss at step 76000: 3.315809
# Average loss at step 78000: 3.349008
# Average loss at step 80000: 3.381414
# Nearest to than: or, but, much, slightly, wondered, nsdap, fermentable, av,
# Nearest to are: were, is, have, being, although, include, while, including,
# Nearest to while: although, when, however, though, after, but, before, during,
# Nearest to over: through, around, counternarcotics, about, ripped, into, win, foray,
# Nearest to from: through, into, khayy, between, within, toward, after, in,
# Nearest to so: too, vauxhall, airspeed, longevity, reinstate, probing, scud, disturb,
# Nearest to six: five, eight, four, seven, three, nine, zero, two,
# Nearest to world: sf, successes, u, gorky, collaborating, bg, ideologue, country,
# Nearest to d: b, j, e, tanker, cysteine, vec, consumer, tyne,
# Nearest to war: dearth, executors, wars, presupposition, heritage, sabra, ghee, guiana,
# Nearest to some: many, several, these, various, any, both, most, aldosterone,
# Nearest to american: british, australian, french, russian, derbyshire, international, canadian, objectivism,
# Nearest to this: it, which, the, she, that, he, revisions, there,
# Nearest to two: three, four, five, six, seven, one, eight, nine,
# Nearest to history: list, description, origins, review, kirghiz, nonsensical, opinion, salamanca,
# Nearest to an: phospholipids, scraped, editable, archangels, thynne, tatra, amtrak, popularizer,
# Average loss at step 82000: 3.409754
# Average loss at step 84000: 3.413615
# Average loss at step 86000: 3.391237
# Average loss at step 88000: 3.352082
# Average loss at step 90000: 3.362823
# Nearest to than: much, or, slightly, fermentable, nsdap, attire, turnout, bernd,
# Nearest to are: were, is, have, include, these, dems, although, paparazzi,
# Nearest to while: although, when, though, after, during, before, were, without,
# Nearest to over: through, around, within, counternarcotics, fantasia, accents, into, foray,
# Nearest to from: through, into, between, under, khayy, during, toward, within,
# Nearest to so: too, vauxhall, longevity, airspeed, thus, therefore, neuroscience, if,
# Nearest to six: seven, eight, five, four, nine, three, two, zero,
# Nearest to world: sf, successes, invulnerable, raves, bg, cocktails, tame, arise,
# Nearest to d: b, vec, tyne, midfielders, j, tanker, cysteine, strains,
# Nearest to war: dearth, executors, wars, heritage, presupposition, sabra, gregorio, alexei,
# Nearest to some: many, several, these, any, both, most, all, this,
# Nearest to american: british, french, australian, russian, italian, international, canadian, european,
# Nearest to this: it, which, another, some, the, revisions, itself, bombardment,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to history: list, description, origins, story, review, viol, leadership, associations,
# Nearest to an: phospholipids, popularizer, another, incapacitation, editable, amtrak, scraped, archangels,
# Average loss at step 92000: 3.397609
# Average loss at step 94000: 3.248666
# Average loss at step 96000: 3.354321
# Average loss at step 98000: 3.241566
# Average loss at step 100000: 3.359772
# Nearest to than: or, slightly, much, fermentable, nsdap, carrera, far, wondered,
# Nearest to are: were, have, be, glorifying, those, these, include, while,
# Nearest to while: although, when, though, after, before, during, buyers, and,
# Nearest to over: counternarcotics, around, within, through, fantasia, gets, finns, cotangent,
# Nearest to from: into, through, in, khayy, across, refrigerants, within, tutu,
# Nearest to so: too, thus, therefore, airspeed, longevity, vauxhall, sometimes, disturb,
# Nearest to six: seven, four, eight, five, nine, three, two, zero,
# Nearest to world: sf, country, successes, season, u, raves, searing, vibrato,
# Nearest to d: b, tanker, c, j, genoa, orthography, edmund, ne,
# Nearest to war: wars, dearth, sabra, executors, behold, presupposition, gregorio, heritage,
# Nearest to some: many, several, these, any, various, certain, all, numerous,
# Nearest to american: british, australian, matriculation, french, comeback, canadian, russian, association,
# Nearest to this: which, it, another, he, levied, disconnect, revisions, the,
# Nearest to two: four, five, three, six, seven, eight, one, zero,
# Nearest to history: list, description, origins, review, effortless, story, invert, sovereigns,
# Nearest to an: grazed, utrecht, popularizer, incapacitation, archangels, brixton, sula, parishes,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch_cbow(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    labels[i, 0] = buffer[skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i, j] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    data:', data[: 8])
    print('    data:', [reverse_dictionary[bi] for bi in data[: 8]])
    print('    batch:', [[reverse_dictionary[bj] for bj in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     data: [5239, 3084, 12, 6, 195, 2, 3137, 46]
#     data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#     batch: [['as', 'anarchism'], ['a', 'originated'], ['term', 'as'], ['of', 'a'], ['abuse', 'term'], ['first', 'of'], ['used', 'abuse'], ['against', 'first']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     data: [5239, 3084, 12, 6, 195, 2, 3137, 46]
#     data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#     batch: [['originated', 'a', 'term', 'anarchism'], ['as', 'term', 'originated', 'of'], ['as', 'of', 'abuse', 'a'], ['abuse', 'a', 'term', 'first'], ['term', 'first', 'used', 'of'], ['of', 'abuse', 'against', 'used'], ['first', 'against', 'abuse', 'early'], ['first', 'working', 'used', 'early']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, skip_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.reduce_sum(
    tf.nn.embedding_lookup(embeddings, train_dataset), 1)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.894748
# Nearest to will: bartos, mullin, own, secession, maoist, outlined, hepburn, tribal,
# Nearest to if: shambhala, rosy, racetrack, fuchs, cim, rifled, gleichschaltung, membership,
# Nearest to three: shambles, arabella, golfer, equals, athenian, lilies, yod, voyages,
# Nearest to the: gigabyte, paphos, missionary, hazing, sveriges, castrated, upbringing, receiver,
# Nearest to so: geologist, clc, cmf, peace, melton, emotional, microtubule, culminated,
# Nearest to world: stalker, classicism, divx, roadmap, nauvoo, yr, honours, palestinians,
# Nearest to they: phanerozoic, cucurbitaceae, regnum, abuser, aucklanders, altered, ostrich, kal,
# Nearest to eight: prokaryotic, abbots, denoted, mammals, turner, claypool, vulnerabilities, diminish,
# Nearest to are: hat, monos, unicast, starling, disinformation, krafft, cracking, draftsman,
# Nearest to one: rowe, mousse, gascony, daime, machete, decommissioned, liberating, recalling,
# Nearest to to: frisbee, visions, ibiblio, calamine, walsh, screwball, egalitarian, caine,
# Nearest to have: vladivostok, obstacle, geocities, respectively, cccc, provenance, previews, presbyterians,
# Nearest to a: aching, downed, zona, finally, sirius, hler, analects, mycenean,
# Nearest to on: cultured, rearrangement, reserving, punitive, pour, dockyard, limes, pareto,
# Nearest to five: dozen, kitsch, syrians, mick, analysis, californian, commune, displaced,
# Nearest to american: translated, bohemia, lapsed, salut, rutland, spore, tiryns, overridden,
# Average loss at step 2000: 4.083925
# Average loss at step 4000: 3.560854
# Average loss at step 6000: 3.386728
# Average loss at step 8000: 3.241459
# Average loss at step 10000: 3.177302
# Nearest to will: can, would, may, bartos, should, weblog, to, could,
# Nearest to if: when, geo, buggery, do, duct, cim, ordain, commas,
# Nearest to three: four, five, seven, six, eight, two, zero, nine,
# Nearest to the: his, their, its, this, dst, a, brunel, frequentist,
# Nearest to so: geologist, cmf, clc, microtubule, oratorios, cam, equator, videos,
# Nearest to world: divx, cleopatra, tomasz, sed, rail, circumflex, phallus, rest,
# Nearest to they: he, there, it, we, who, she, cucurbitaceae, often,
# Nearest to eight: nine, six, four, seven, five, three, zero, two,
# Nearest to are: were, is, have, was, undeniable, duchy, degrading, avercamp,
# Nearest to one: two, four, eight, three, six, nine, seven, five,
# Nearest to to: would, may, will, can, egalitarian, could, mesocricetus, walsh,
# Nearest to have: had, has, were, be, are, having, armand, bored,
# Nearest to a: rhythmically, the, ameliorate, latour, very, playa, zona, turquoise,
# Nearest to on: in, collins, rearrangement, at, counterintuitive, cabot, adv, during,
# Nearest to five: six, four, eight, three, seven, nine, zero, two,
# Nearest to american: french, emanates, overridden, english, farewell, tiryns, smilga, gum,
# Average loss at step 12000: 3.199305
# Average loss at step 14000: 3.159862
# Average loss at step 16000: 3.179465
# Average loss at step 18000: 3.130150
# Average loss at step 20000: 2.996269
# Nearest to will: can, would, may, could, should, must, might, cannot,
# Nearest to if: when, though, where, geo, predictability, roundhouse, beno, urbanization,
# Nearest to three: six, five, seven, eight, four, two, nine, zero,
# Nearest to the: a, his, their, its, turquoise, this, any, your,
# Nearest to so: cmf, geologist, gears, devotions, oratorios, ness, alone, caesura,
# Nearest to world: circumflex, divx, rest, phallus, playing, cupola, progenitor, civil,
# Nearest to they: there, we, he, you, it, she, who, these,
# Nearest to eight: six, seven, nine, five, four, three, zero, two,
# Nearest to are: were, have, is, include, hammered, be, degrading, nowadays,
# Nearest to one: two, seven, six, eight, three, four, five, delaying,
# Nearest to to: frisbee, condenses, would, snopes, madelyne, can, could, not,
# Nearest to have: has, had, were, are, be, nostra, refer, octagonal,
# Nearest to a: the, any, strongholds, courtship, policing, playa, his, guoyu,
# Nearest to on: upon, at, rearrangement, during, in, about, towards, through,
# Nearest to five: six, seven, eight, three, four, nine, zero, two,
# Nearest to american: english, british, french, brooklyn, australian, german, canadian, italian,
# Average loss at step 22000: 3.076642
# Average loss at step 24000: 3.042676
# Average loss at step 26000: 3.002337
# Average loss at step 28000: 3.032916
# Average loss at step 30000: 3.007888
# Nearest to will: would, can, could, may, must, should, cannot, might,
# Nearest to if: when, though, where, although, after, before, since, without,
# Nearest to three: four, five, six, two, eight, seven, nine, one,
# Nearest to the: their, a, this, its, perk, these, cloak, dst,
# Nearest to so: geologist, creatures, torquay, oratorios, sometimes, argue, very, devotions,
# Nearest to world: divx, circumflex, oder, civil, phallus, rest, u, wingless,
# Nearest to they: we, there, he, you, she, it, these, who,
# Nearest to eight: nine, seven, six, four, five, three, two, zero,
# Nearest to are: were, have, is, include, hammered, remain, anakin, those,
# Nearest to one: two, three, four, five, six, seven, shahanshah, eight,
# Nearest to to: would, can, will, could, must, may, xbox, condenses,
# Nearest to have: had, has, are, were, having, refer, be, produce,
# Nearest to a: the, rhythmically, any, another, trianon, anywhere, realistically, ingots,
# Nearest to on: upon, in, through, towards, collins, about, logograms, under,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to american: australian, french, german, canadian, italian, piraeus, brooklyn, british,
# Average loss at step 32000: 2.830903
# Average loss at step 34000: 2.957708
# Average loss at step 36000: 2.943977
# Average loss at step 38000: 2.943594
# Average loss at step 40000: 2.928370
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to if: when, though, where, follows, since, after, without, before,
# Nearest to three: five, four, six, two, eight, seven, zero, nine,
# Nearest to the: their, your, its, his, dst, a, perk, her,
# Nearest to so: torquay, then, cmf, if, debatable, cakes, sometimes, karaca,
# Nearest to world: u, divx, interdependent, definite, dreamed, rest, term, phallus,
# Nearest to they: we, he, there, you, she, who, i, it,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Nearest to are: were, have, is, include, undeniable, including, alkaloids, hammered,
# Nearest to one: two, six, three, seven, five, four, eight, marinus,
# Nearest to to: frisbee, will, would, cavitation, screwball, ibiblio, must, towards,
# Nearest to have: had, has, were, are, be, having, include, refer,
# Nearest to a: another, rhythmically, turquoise, the, policing, his, fitna, spacewalks,
# Nearest to on: upon, collins, under, within, via, through, greenish, breed,
# Nearest to five: six, four, seven, eight, three, two, nine, zero,
# Nearest to american: british, italian, canadian, german, australian, african, western, international,
# Average loss at step 42000: 2.955477
# Average loss at step 44000: 2.957375
# Average loss at step 46000: 2.910527
# Average loss at step 48000: 2.867648
# Average loss at step 50000: 2.848923
# Nearest to will: would, may, could, can, should, must, might, cannot,
# Nearest to if: when, though, where, before, while, since, without, because,
# Nearest to three: four, two, seven, six, five, eight, nine, zero,
# Nearest to the: their, any, its, a, strongholds, cris, dst, perk,
# Nearest to so: then, sometimes, distillation, torquay, inescapable, ski, aarseth, cakes,
# Nearest to world: cupola, divx, rajah, ech, annabel, u, registry, rest,
# Nearest to they: we, there, he, you, she, it, these, penzance,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to are: were, is, have, include, alkaloids, while, be, contain,
# Nearest to one: two, four, seven, three, six, eight, zero, percent,
# Nearest to to: will, must, could, disclaimed, towards, thrice, frisbee, dread,
# Nearest to have: had, has, include, having, refer, produce, be, contain,
# Nearest to a: any, policing, the, another, strongholds, anywhere, spacewalks, every,
# Nearest to on: upon, under, against, crypto, in, pizarro, within, through,
# Nearest to five: four, seven, eight, six, three, nine, zero, two,
# Nearest to american: british, german, italian, canadian, french, piraeus, australian, smilga,
# Average loss at step 52000: 2.891229
# Average loss at step 54000: 2.865436
# Average loss at step 56000: 2.862657
# Average loss at step 58000: 2.750518
# Average loss at step 60000: 2.830734
# Nearest to will: would, can, could, should, may, might, must, cannot,
# Nearest to if: when, though, where, after, before, since, while, did,
# Nearest to three: four, two, six, five, seven, eight, nine, one,
# Nearest to the: their, any, its, a, his, this, mubarak, each,
# Nearest to so: sometimes, too, how, asserting, inescapable, diabetics, hgp, if,
# Nearest to world: divx, phallus, registry, u, wingless, ech, plexus, publication,
# Nearest to they: we, he, you, there, she, it, these, not,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to are: were, include, is, have, contain, including, be, remain,
# Nearest to one: two, four, three, five, six, seven, eight, nine,
# Nearest to to: will, would, condenses, offal, frisbee, must, disclaimed, could,
# Nearest to have: had, has, having, refer, were, are, contain, be,
# Nearest to a: the, another, policing, rhythmically, convincing, any, strongholds, boziz,
# Nearest to on: upon, within, through, at, in, towards, during, rearrangement,
# Nearest to five: four, six, seven, eight, nine, three, zero, two,
# Nearest to american: british, african, canadian, australian, italian, german, irish, english,
# Average loss at step 62000: 2.836114
# Average loss at step 64000: 2.773169
# Average loss at step 66000: 2.763090
# Average loss at step 68000: 2.713586
# Average loss at step 70000: 2.789642
# Nearest to will: would, could, can, should, may, must, might, cannot,
# Nearest to if: when, though, since, before, after, follows, where, without,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to the: its, their, his, a, any, your, an, margrethe,
# Nearest to so: too, inescapable, sometimes, how, astrophysics, enough, hgp, very,
# Nearest to world: divx, phallus, visible, u, registry, holy, enciphered, mosque,
# Nearest to they: we, he, you, there, she, these, it, koyaanisqatsi,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to are: were, include, is, contain, have, hammered, including, those,
# Nearest to one: two, seven, three, five, eight, six, four, nine,
# Nearest to to: will, would, formic, can, ingenious, must, could, condenses,
# Nearest to have: had, has, having, include, refer, contain, require, receive,
# Nearest to a: another, the, any, policing, strongholds, latour, shreck, galina,
# Nearest to on: upon, in, under, within, through, at, during, around,
# Nearest to five: six, seven, three, eight, four, nine, zero, two,
# Nearest to american: british, australian, canadian, african, english, austrian, polytechnic, italian,
# Average loss at step 72000: 2.796383
# Average loss at step 74000: 2.646617
# Average loss at step 76000: 2.803662
# Average loss at step 78000: 2.832751
# Average loss at step 80000: 2.776933
# Nearest to will: would, could, can, should, must, may, might, cannot,
# Nearest to if: when, though, where, before, since, follows, did, unless,
# Nearest to three: four, five, two, six, eight, seven, nine, one,
# Nearest to the: their, its, any, mubarak, his, responsiveness, a, dst,
# Nearest to so: too, sometimes, how, inescapable, thus, agnosticism, then, karaca,
# Nearest to world: divx, u, cupola, interdependent, rajah, ballot, enciphered, phallus,
# Nearest to they: we, you, he, she, there, it, i, these,
# Nearest to eight: nine, six, seven, five, four, three, two, zero,
# Nearest to are: were, is, include, have, contain, alkaloids, hammered, be,
# Nearest to one: two, six, seven, three, four, five, eight, spite,
# Nearest to to: could, would, formic, should, can, will, must, cannot,
# Nearest to have: had, has, refer, were, are, contain, having, include,
# Nearest to a: another, policing, strongholds, boziz, the, rhythmically, every, any,
# Nearest to on: upon, in, during, around, crypto, through, mentat, against,
# Nearest to five: six, seven, four, eight, three, nine, two, zero,
# Nearest to american: african, australian, canadian, british, italian, soviet, german, irish,
# Average loss at step 82000: 2.668824
# Average loss at step 84000: 2.774597
# Average loss at step 86000: 2.733418
# Average loss at step 88000: 2.753665
# Average loss at step 90000: 2.738554
# Nearest to will: would, can, could, should, must, may, might, cannot,
# Nearest to if: when, though, before, where, without, follows, did, after,
# Nearest to three: four, five, two, six, seven, eight, nine, twenty,
# Nearest to the: its, his, their, your, our, this, perk, any,
# Nearest to so: too, sometimes, if, hgp, karaca, agnosticism, murad, dimers,
# Nearest to world: divx, u, lubricated, phallus, faithful, kano, hurry, publication,
# Nearest to they: we, he, you, there, she, it, i, who,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to are: were, is, have, include, contain, including, exist, bluebird,
# Nearest to one: two, four, eight, six, seven, three, fact, spite,
# Nearest to to: would, towards, ibiblio, should, must, could, will, thrice,
# Nearest to have: had, has, were, refer, having, contain, are, require,
# Nearest to a: another, policing, rhythmically, spacewalks, the, overweight, preventative, strongholds,
# Nearest to on: upon, in, through, onto, within, against, at, about,
# Nearest to five: four, six, seven, three, eight, zero, nine, two,
# Nearest to american: african, canadian, australian, british, indian, italian, international, irish,
# Average loss at step 92000: 2.672782
# Average loss at step 94000: 2.721935
# Average loss at step 96000: 2.699820
# Average loss at step 98000: 2.364977
# Average loss at step 100000: 2.401337
# Nearest to will: would, could, can, should, must, might, cannot, may,
# Nearest to if: when, though, before, follows, after, where, although, did,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to the: his, our, their, its, my, her, your, a,
# Nearest to so: too, sometimes, if, thus, very, godavari, agnosticism, karaca,
# Nearest to world: divx, year, u, tournament, vietnam, anatomists, forl, interdependent,
# Nearest to they: we, he, you, there, she, i, it, who,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to are: were, have, include, contain, is, remain, be, was,
# Nearest to one: two, three, five, six, seven, four, spite, gul,
# Nearest to to: would, must, shall, helped, should, might, will, could,
# Nearest to have: had, has, having, are, contain, refer, include, were,
# Nearest to a: rhythmically, another, policing, the, hillsides, boziz, lehi, strongholds,
# Nearest to on: upon, in, telling, at, crypto, counterintuitive, against, logograms,
# Nearest to five: seven, four, six, eight, nine, three, two, zero,
# Nearest to american: canadian, english, australian, british, italian, german, irish, french,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points + 1, :])

def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points + 1)]
plot(two_d_embeddings, words)
